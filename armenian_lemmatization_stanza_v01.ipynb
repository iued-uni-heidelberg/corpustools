# %% [markdown]
# <a href="https://colab.research.google.com/github/iued-uni-heidelberg/corpustools/blob/main/armenian_lemmatization_stanza_v01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spacy-stanza

# %%
import stanza
import spacy_stanza

# Download the stanza model if necessary
stanza.download("en")

# Initialize the pipeline
nlp = spacy_stanza.load_pipeline("en")

doc = nlp("Barack Obama was born in Hawaii. He was elected president in 2008.")
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.dep_, token.ent_type_)
print(doc.ents)
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json:   0%|   …
# INFO:stanza:Downloading default packages for language: en (English) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.4.1/models/default.zip:   0%|          | 0…
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources.
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ============================
# | Processor    | Package   |
# ----------------------------
# | tokenize     | combined  |
# | pos          | combined  |
# | lemma        | combined  |
# | depparse     | combined  |
# | sentiment    | sstplus   |
# | constituency | wsj       |
# | ner          | ontonotes |
# ============================
#
# INFO:stanza:Use device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Loading: sentiment
# INFO:stanza:Loading: constituency
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!
# Barack Barack PROPN nsubj:pass PERSON
# Obama Obama PROPN flat PERSON
# was be AUX aux:pass
# born bear VERB root
# in in ADP case
# Hawaii Hawaii PROPN obl GPE
# . . PUNCT punct
# He he PRON nsubj:pass
# was be AUX aux:pass
# elected elect VERB root
# president president NOUN xcomp
# in in ADP case
# 2008 2008 NUM obl DATE
# . . PUNCT punct
# (Barack Obama, Hawaii, 2008)

# %%
stanza.download("hy")
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json:   0%|   …
# INFO:stanza:Downloading default packages for language: hy (Armenian) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-hy/resolve/v1.4.1/models/default.zip:   0%|          | 0…
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources.

# %%
nlp_hy = spacy_stanza.load_pipeline("hy")
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json:   0%|   …
# INFO:stanza:Loading these models for language: hy (Armenian):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | armtdp  |
# | mwt       | armtdp  |
# | pos       | armtdp  |
# | lemma     | armtdp  |
# | depparse  | armtdp  |
# =======================
#
# INFO:stanza:Use device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!

# %%
doc = nlp_hy("ՄԱՐԴՈՒ ԻՐԱՎՈՒՆՔՆԵՐԻ ՀԱՄԸՆԴՀԱՆՈՒՐ ՀՌՉԱԿԱԳԻՐ. ՆԵՐԱԾԱԿԱՆ. Քանզի մարդկային ընտանիքի բոլոր անդամներին ներհատուկ արժանապատվությունըև հավասար ու անօտարելի իրավունքները աշխարհի ազատության, արդարության ու խաղաղության հիմքն են.")

# %%
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.dep_, token.ent_type_)
# Out:
# ՄԱՐԴՈՒ մարդ NOUN nmod:poss
# ԻՐԱՎՈՒՆՔՆԵՐԻ իրադումյուն NOUN nmod:poss
# ՀԱՄԸՆԴՀԱՆՈՒՐ համրումյուն NOUN nmod
# ՀՌՉԱԿԱԳԻՐ հռչակագիր NUM nummod
# . . PUNCT punct
# ՆԵՐԱԾԱԿԱՆ ներածական NOUN flat
# . . PUNCT punct
# Քանզի քանզի ADV advmod
# մարդկային մարդկային ADJ amod
# ընտանիքի ընտանիք NOUN nmod:poss
# բոլոր բոլոր DET det
# անդամներին անդամ NOUN nmod:npmod
# ներհատուկ ներհատուկ ADJ amod
# արժանապատվությունըև արժանապատվություն NOUN nsubj
# հավասար հավասար ADJ amod
# ու ու CCONJ cc
# անօտարելի անօտարելի ADJ conj
# իրավունքները իրավունք NOUN nsubj
# աշխարհի աշխարհ NOUN nmod:poss
# ազատության ազատություն NOUN nmod:poss
# , , PUNCT punct
# արդարության արդարություն NOUN conj
# ու ու CCONJ cc
# խաղաղության խաղաղություն NOUN conj
# հիմքն հիմք NOUN root
# են եմ AUX cop
# . . PUNCT punct

# %%
print(doc.ents)
# Out:
# ()

# %%
with open('/content/udhr-hy.txt', 'r', encoding='utf-8') as infile, open('/content/udhr-hy-analysis.txt', 'w') as outfile:
    # read sample.txt an and write its content into sample2.txt
    outfile.write("{token.text}\t{token.lemma_}\t{token.pos_}\t{token.dep_}\t{parentLem}\t{LAncestors}\n")
    for line in infile:
        line = line.strip()
        doc = nlp_hy(line)
        # outfile.write(line + '\n')
        for token in doc:
            LAncestors = list(token.ancestors)
            print(str(LAncestors))
            try:
                SLAncestors = str(list(token.ancestors))
                parent = LAncestors[0]
                parentLem = parent.lemma_
            except:
                parentLem = "NONE"
            outfile.write(f"{token.text}\t{token.lemma_}\t{token.pos_}\t{token.dep_}\t{parentLem}\t{SLAncestors}\n")
# Out:
# [ԻՐԱՎՈՒՆՔՆԵՐԻ]
# []
# [ԻՐԱՎՈՒՆՔՆԵՐԻ]
# [ՀԱՄԸՆԴՀԱՆՈՒՐ, ԻՐԱՎՈՒՆՔՆԵՐԻ]
# []
# [skj]
# [skj]
# [jisj, skj]
# [oj, skj]
# [oj, skj]
# [օիյոօյֆ]
# [օիյոօյֆ]
# [օիյոօյֆ]
# []
# [օիյոօյֆ]
# [օիյոօյֆ]
# []
# [հիմքն]
# [ընտանիքի, անդամներին, հիմքն]
# [անդամներին, հիմքն]
# [անդամներին, հիմքն]
# [հիմքն]
# [արժանապատվությունըև, հիմքն]
# [հիմքն]
# [իրավունքները, հիմքն]
# [անօտարելի, հավասար, իրավունքները, հիմքն]
# [հավասար, իրավունքները, հիմքն]
# [հիմքն]
# [ազատության, հիմքն]
# [հիմքն]
# [արդարության, ազատության, հիմքն]
# [ազատության, հիմքն]
# [խաղաղության, ազատության, հիմքն]
# [ազատության, հիմքն]
# []
# [հիմքն]
# [հիմքն]
# [հանգեցրել]
# [վունքների, հանգեցրել]
# [վունքների, հանգեցրել]
# [հանգեցրել]
# [վունքների, հանգեցրել]
# [հանգեցրել]
# [արհամարհանքը, քամահրանքն, հանգեցրել]
# [քամահրանքն, հանգեցրել]
# []
# [հանգեցրել]
# [խիղճը, խռոված, գործողությունների, հանգեցրել]
# [խռոված, գործողությունների, հանգեցրել]
# [գործողությունների, հանգեցրել]
# [գործողությունների, հանգեցրել]
# [հանգեցրել]
# [հռչակվել, հանգեցրել]
# [հռչակվել, հանգեցրել]
# [քանի, հռչակվել, հանգեցրել]
# [աշխարհի, ստեղծումը, հռչակվել, հանգեցրել]
# [ստեղծումը, հռչակվել, հանգեցրել]
# [հռչակվել, հանգեցրել]
# [կվայելեն, ստեղծումը, հռչակվել, հանգեցրել]
# [կվայելեն, ստեղծումը, հռչակվել, հանգեցրել]
# [կվայելեն, ստեղծումը, հռչակվել, հանգեցրել]
# [ստեղծումը, հռչակվել, հանգեցրել]
# [ազատությունև, զերծ, կվայելեն, ստեղծումը, հռչակվել, հանգեցրել]
# [համոզմունքների, խոսքի, ազատությունև, զերծ, կվայելեն, ստեղծումը, հռչակվել, հանգեցրել]
# [խոսքի, ազատությունև, զերծ, կվայելեն, ստեղծումը, հռչակվել, հանգեցրել]
# [զերծ, կվայելեն, ստեղծումը, հռչակվել, հանգեցրել]
# [կվայելեն, ստեղծումը, հռչակվել, հանգեցրել]
# [զերծ, կվայելեն, ստեղծումը, հռչակվել, հանգեցրել]
# [զերծ, կվայելեն, ստեղծումը, հռչակվել, հանգեցրել]
# [հռչակվել, հանգեցրել]
# [հռչակվել, հանգեցրել]
# [հանգեցրել]
# [հռչակվել, հանգեցրել]
# [ձգտում, հռչակվել, հանգեցրել]
# [ձգտում, հռչակվել, հանգեցրել]
# [ձգտում, հռչակվել, հանգեցրել]
# [հռչակվել, հանգեցրել]
# [հանգեցրել]
# [անհրաժեշտ]
# []
# [անհրաժեշտ]
# [չդիմի, անհրաժեշտ]
# [չդիմի, անհրաժեշտ]
# [չդիմի, անհրաժեշտ]
# [միջոցի, չդիմի, անհրաժեշտ]
# [միջոցի, չդիմի, անհրաժեշտ]
# [միջոցի, չդիմի, անհրաժեշտ]
# [միջոցի, չդիմի, անհրաժեշտ]
# [չդիմի, անհրաժեշտ]
# [չդիմի, անհրաժեշտ]
# [անհրաժեշտ]
# [ընդդեմ, բռնության, չդիմի, անհրաժեշտ]
# [բռնության, չդիմի, անհրաժեշտ]
# [չդիմի, անհրաժեշտ]
# [ճնշման, բռնության, չդիմի, անհրաժեշտ]
# [բռնության, չդիմի, անհրաժեշտ]
# [պաշտպանել, չդիմի, անհրաժեշտ]
# [իշխանությամբ, պաշտպանել, չդիմի, անհրաժեշտ]
# [պաշտպանել, չդիմի, անհրաժեշտ]
# [չդիմի, անհրաժեշտ]
# [իրավունքները, պաշտպանել, չդիմի, անհրաժեշտ]
# [պաշտպանել, չդիմի, անհրաժեշտ]
# [անհրաժեշտ]
# [անհրաժեշտ]
# []
# [անհրաժեշտ]
# [անհրաժեշտ]
# [հարաբերությունների, զարգացմանը, նպաստել, անհրաժեշտ]
# [ազգերի, հարաբերությունների, զարգացմանը, նպաստել, անհրաժեշտ]
# [հարաբերությունների, զարգացմանը, նպաստել, անհրաժեշտ]
# [զարգացմանը, նպաստել, անհրաժեշտ]
# [նպաստել, անհրաժեշտ]
# [անհրաժեշտ]
# [վերահավաստել]
# [ազգերի, ժողովուրդները, վերահավաստել]
# [ժողովուրդները, վերահավաստել]
# [վերահավաստել]
# [վերահավաստել]
# [կանոնադրության, վերահավաստել]
# []
# [վերահավաստել]
# [հավատը, վերահավաստել]
# [վերահավաստել]
# [իրավունքների, վերահավաստել]
# [իրավունքների, վերահավաստել]
# [վերահավաստել]
# [արժանապատվության, իրավունքների, վերահավաստել]
# [արժանապատվության, իրավունքների, վերահավաստել]
# [իրավունքների, վերահավաստել]
# [արժեքի, իրավունքների, վերահավաստել]
# [իրավունքների, վերահավաստել]
# [տղամարդու, իրավունքների, վերահավաստել]
# [իրավունքների, վերահավաստել]
# [իրավունքների, նկատմամբև, որոշել, վերահավաստել]
# [իրավունքների, նկատմամբև, որոշել, վերահավաստել]
# [իրավունքների, նկատմամբև, որոշել, վերահավաստել]
# [նկատմամբև, որոշել, վերահավաստել]
# [որոշել, վերահավաստել]
# [վերահավաստել]
# [որոշել, վերահավաստել]
# [մեծ, ազատության, պայմաններում, նպաստել, որոշել, վերահավաստել]
# [ազատության, պայմաններում, նպաստել, որոշել, վերահավաստել]
# [պայմաններում, նպաստել, որոշել, վերահավաստել]
# [նպաստել, որոշել, վերահավաստել]
# [որոշել, վերահավաստել]
# [առաջընթացին, նպաստել, որոշել, վերահավաստել]
# [նպաստել, որոշել, վերահավաստել]
# [պայմանների, առաջընթացին, նպաստել, որոշել, վերահավաստել]
# [պայմանների, առաջընթացին, նպաստել, որոշել, վերահավաստել]
# [առաջընթացին, նպաստել, որոշել, վերահավաստել]
# [առաջընթացին, նպաստել, որոշել, վերահավաստել]
# [վերահավաստել]
# [պարտավորվել]
# [պետությունները, պարտավորվել]
# [պարտավորվել]
# []
# [պարտավորվել]
# [ազգերի, համագործակցությամբ, հասնել, պարտավորվել]
# [համագործակցությամբ, հասնել, պարտավորվել]
# [ազգերի, համագործակցությամբ, հասնել, պարտավորվել]
# [հասնել, պարտավորվել]
# [պարտավորվել]
# [իրավունքների, հարգանքի, հասնել, պարտավորվել]
# [հարգանքի, հասնել, պարտավորվել]
# [ազատությունների, իրավունքների, հարգանքի, հասնել, պարտավորվել]
# [ազատությունների, իրավունքների, հարգանքի, հասնել, պարտավորվել]
# [իրավունքների, հարգանքի, հասնել, պարտավորվել]
# [իրավունքների, հարգանքի, հասնել, պարտավորվել]
# [հարգանքի, հասնել, պարտավորվել]
# [հասնել, պարտավորվել]
# [պահպանման, հարգանքի, հասնել, պարտավորվել]
# [պահպանման, հարգանքի, հասնել, պարտավորվել]
# [հարգանքի, հասնել, պարտավորվել]
# [պարտավորվել]
# [ունի]
# [իրավունքների, ըմբռնումը, ունի]
# [ըմբռնումը, ունի]
# [ազատությունների, իրավունքների, ըմբռնումը, ունի]
# [իրավունքների, ըմբռնումը, ունի]
# [ըմբռնումը, ունի]
# [ունի]
# [նշանակություն, ունի]
# [ունի]
# []
# [վորութ, ունի]
# [վորութ, ունի]
# [ունի]
# [իրագործման, ունի]
# [իրագործման, ունի]
# [ունի]
# [իրագործման, ունի]
# [ունի]
# [ԱՍԱՄԲԼԵԱՆ]
# []
# []
# [ազդարարում]
# [ազդարարում]
# [ԻՐԱՎՈՒՆՔՆԵՐԻ, ՀՌՉԱԿԱԳԻՐԸ]
# [ՀՌՉԱԿԱԳԻՐԸ]
# [ՀՌՉԱԿԱԳԻՐԸ]
# []
# [առաջադրանք, ժողովուրդներին, ձգտի]
# [ժողովուրդներին, ձգտի]
# [ժողովուրդներին, ձգտի]
# [ձգտի]
# [ազգերին, ժողովուրդներին, ձգտի]
# [ժողովուրդներին, ձգտի]
# [ձգտի]
# [ձգտի]
# [հասարակության, մարմին, ձգտի]
# [հասարակության, մարմին, ձգտի]
# [մարմին, ձգտի]
# [մարմին, ձգտի]
# [ձգտի]
# [ունենալով, ձգտի]
# [ունենալով, ձգտի]
# [ունենալով, ձգտի]
# [ձգտի]
# [Հռչակագիրը, ունենալով, ձգտի]
# [ունենալով, ձգտի]
# [ձգտի]
# []
# [ձգտի]
# [կրթության, ուսուցման, ձգտի]
# [ուսուցման, ձգտի]
# [ուսուցման, ձգտի]
# [ձգտի]
# [իրավունքների, հարգալից, վերաբերմունքինև, ապահովել, նպաստել, ձգտի]
# [հարգալից, վերաբերմունքինև, ապահովել, նպաստել, ձգտի]
# [ազատությունների, իրավունքների, հարգալից, վերաբերմունքինև, ապահովել, նպաստել, ձգտի]
# [իրավունքների, հարգալից, վերաբերմունքինև, ապահովել, նպաստել, ձգտի]
# [իրավունքների, հարգալից, վերաբերմունքինև, ապահովել, նպաստել, ձգտի]
# [վերաբերմունքինև, ապահովել, նպաստել, ձգտի]
# [ապահովել, նպաստել, ձգտի]
# [միջոցառումներով, ապահովել, նպաստել, ձգտի]
# [միջազգային, ազգային, միջոցառումներով, ապահովել, նպաստել, ձգտի]
# [ազգային, միջոցառումներով, ապահովել, նպաստել, ձգտի]
# [միջոցառումներով, ապահովել, նպաստել, ձգտի]
# [ապահովել, նպաստել, ձգտի]
# [նպաստել, ձգտի]
# [ճանաչումն, ապահովել, նպաստել, ձգտի]
# [ճանաչումն, ապահովել, նպաստել, ձգտի]
# [ճանաչումն, ապահովել, նպաստել, ձգտի]
# [ապահովել, նպաստել, ձգտի]
# [պահպանումը, ճանաչումն, ապահովել, նպաստել, ձգտի]
# [ճանաչումն, ապահովել, նպաստել, ձգտի]
# [ժողովուրդներիև, ժողովուրդների, ճանաչումն, ապահովել, նպաստել, ձգտի]
# [պետությունների, ժողովուրդներիև, ժողովուրդների, ճանաչումն, ապահովել, նպաստել, ձգտի]
# [ժողովուրդներիև, ժողովուրդների, ճանաչումն, ապահովել, նպաստել, ձգտի]
# [ժողովուրդների, ճանաչումն, ապահովել, նպաստել, ձգտի]
# [ժողովուրդների, ճանաչումն, ապահովել, նպաստել, ձգտի]
# [տարածքների, ժողովուրդների, ճանաչումն, ապահովել, նպաստել, ձգտի]
# [տարածքների, ժողովուրդների, ճանաչումն, ապահովել, նպաստել, ձգտի]
# [ժողովուրդների, ճանաչումն, ապահովել, նպաստել, ձգտի]
# [ճանաչումն, ապահովել, նպաստել, ձգտի]
# [ժողովուրդների, ճանաչումն, ապահովել, նպաստել, ձգտի]
# [ձգտի]
# []
# [Հոդված]
# [մարդիկ, ծնվում]
# [ծնվում]
# []
# [ծնվում]
# [ծնվում]
# [հավասար, ազատ, ծնվում]
# [ազատ, ծնվում]
# [արժանապատվությամբ, ծնվում]
# [ծնվում]
# [իրավունքներով, արժանապատվությամբ, ծնվում]
# [արժանապատվությամբ, ծնվում]
# [ծնվում]
# [ունեն]
# []
# [ունեն]
# [վերաբերվեն, ունեն]
# [միմյանց, վերաբերվեն, ունեն]
# [վերաբերվեն, ունեն]
# [վերաբերվեն, ունեն]
# [վերաբերվեն, ունեն]
# [վերաբերվեն, ունեն]
# [ունեն]
# [ունեն]
# []
# [Հոդված]
# [ունի]
# [Ամեն, ունի]
# []
# [Հռչակագրում, բերված, իրավունքներն, ունի]
# [բերված, իրավունքներն, ունի]
# [իրավունքներն, ունի]
# [իրավունքներն, ունի]
# [ունի]
# [ազատությունները, իրավունքներն, ունի]
# [իրավունքներն, ունի]
# [խտրության, հիմնված, ունի]
# [խտրության, հիմնված, ունի]
# [հիմնված, ունի]
# [հիմնված, ունի]
# [ունի]
# [հիմնված, ունի]
# [գույնի, ցեղային, հիմնված, ունի]
# [գույնի, ցեղային, հիմնված, ունի]
# [ցեղային, հիմնված, ունի]
# [սեռի, ցեղային, հիմնված, ունի]
# [ցեղային, հիմնված, ունի]
# [լեզվի, ցեղային, հիմնված, ունի]
# [ցեղային, հիմնված, ունի]
# [կրոնի, ցեղային, հիմնված, ունի]
# [ցեղային, հիմնված, ունի]
# [համոզմունքների, ցեղային, հիմնված, ունի]
# [համոզմունքների, ցեղային, հիմնված, ունի]
# [այլ, քաղաքական, համոզմունքների, ցեղային, հիմնված, ունի]
# [քաղաքական, համոզմունքների, ցեղային, հիմնված, ունի]
# [ցեղային, հիմնված, ունի]
# [ծագման, ցեղային, հիմնված, ունի]
# [ծագման, ցեղային, հիմնված, ունի]
# [սոցիալական, ազգային, ծագման, ցեղային, հիմնված, ունի]
# [ազգային, ծագման, ցեղային, հիմնված, ունի]
# [ցեղային, հիմնված, ունի]
# [ունեցվածքի, ծագման, ցեղային, հիմնված, ունի]
# [ծագման, ցեղային, հիմնված, ունի]
# [պատկանելության, ցեղային, հիմնված, ունի]
# [պատկանելության, ցեղային, հիմնված, ունի]
# [ցեղային, հիմնված, ունի]
# [որեւէ, պատկանելության, ցեղային, հիմնված, ունի]
# [պատկանելության, ցեղային, հիմնված, ունի]
# [կարգավիճակի, ծագման, ցեղային, հիմնված, ունի]
# [ծագման, ցեղային, հիմնված, ունի]
# [ցեղային, հիմնված, ունի]
# [ունի]
# [լինի]
# [լինի]
# [խտրականություն, լինի]
# [ոչ, խտրականություն, լինի]
# [լինի]
# [լինի]
# [լինի]
# []
# [լինի]
# [հիմնված, լինի]
# [տարածքի, երկրի, հիմնված, լինի]
# [երկրի, հիմնված, լինի]
# [կարգավիճակի, երկրի, հիմնված, լինի]
# [կարգավիճակի, երկրի, հիմնված, լինի]
# [իրավական, քաղաքական, կարգավիճակի, երկրի, հիմնված, լինի]
# [քաղաքական, կարգավիճակի, երկրի, հիմնված, լինի]
# [կարգավիճակի, երկրի, հիմնված, լինի]
# [միջազգային, կարգավիճակի, երկրի, հիմնված, լինի]
# [կարգավիճակի, երկրի, հիմնված, լինի]
# [երկրի, հիմնված, լինի]
# [երկրի, հիմնված, լինի]
# [լինի, լինի]
# [լինի]
# [լինի, լինի]
# [որեւէ, լինի, լինի]
# [խնամարկյալ, անկախ, որեւէ, լինի, լինի]
# [անկախ, որեւէ, լինի, լինի]
# [ոչինքնակառավարվող, անկախ, որեւէ, լինի, լինի]
# [անկախ, որեւէ, լինի, լինի]
# [ինքնիշխանության, անկախ, որեւէ, լինի, լինի]
# [անկախ, որեւէ, լինի, լինի]
# [լինի, լինի]
# [սահմանափակումով, կազմավորում, որեւէ, լինի, լինի]
# [կազմավորում, որեւէ, լինի, լինի]
# [կազմավորում, որեւէ, լինի, լինի]
# [որեւէ, լինի, լինի]
# [պատկանում, կազմավորում, որեւէ, լինի, լինի]
# [պատկանում, կազմավորում, որեւէ, լինի, լինի]
# [կազմավորում, որեւէ, լինի, լինի]
# [պատկանում, կազմավորում, որեւէ, լինի, լինի]
# [պատկանում, կազմավորում, որեւէ, լինի, լինի]
# [լինի]
# []
# [Հոդված]
# [ունի]
# [Յուրաքանչյուր, ունի]
# []
# [իրավունք, ունի]
# [ազատության, ապրելու, իրավունք, ունի]
# [ապրելու, իրավունք, ունի]
# [անձի, ազատության, ապրելու, իրավունք, ունի]
# [ազատության, ապրելու, իրավունք, ունի]
# [իրավունք, ունի]
# [ունի]
# [ունի]
# []
# [Հոդված]
# [լինի]
# [Ոչ, լինի]
# [լինի]
# [լինի]
# []
# [վիճակում, լինի]
# [անազատ, ստրկության, վիճակում, լինի]
# [ստրկության, վիճակում, լինի]
# [լինի]
# [արգելվեն, լինի]
# [արգելվեն, լինի]
# [արգելվեն, լինի]
# [լինի]
# [ձեւերը, արգելվեն, լինի]
# [առուծախի, ստրկատիրության, ձեւերը, արգելվեն, լինի]
# [առուծախի, ստրկատիրության, ձեւերը, արգելվեն, լինի]
# [ստրկատիրության, ձեւերը, արգելվեն, լինի]
# [ձեւերը, արգելվեն, լինի]
# [արգելվեն, լինի]
# [լինի]
# []
# [Հոդված]
# [ենթարկվի]
# [Ոչ, ենթարկվի]
# [ենթարկվի]
# [ենթարկվի]
# []
# [ենթարկվի]
# [դաժան, կտտանքների, ենթարկվի]
# [կտտանքների, ենթարկվի]
# [անմարդկային, կտտանքների, ենթարկվի]
# [կտտանքների, ենթարկվի]
# [ստորացուցիչ, կտտանքների, ենթարկվի]
# [կտտանքների, ենթարկվի]
# [ենթարկվի]
# [պատժի, վերաբերմունքի, ենթարկվի]
# [վերաբերմունքի, ենթարկվի]
# [ենթարկվի]
# []
# [Հոդված]
# [ունի]
# [Ամեն, ունի]
# [լինի, Ամեն, ունի]
# [լինի, Ամեն, ունի]
# [ուր, լինի, Ամեն, ունի]
# [լինի, Ամեն, ունի]
# [Ամեն, ունի]
# [ունի]
# [ունի]
# []
# [ունի]
# [իրավասուբյեկտ, ճանաչվել, ունի]
# [ճանաչվել, ունի]
# [ունի]
# []
# [Հոդված]
# [հավասար]
# []
# [հավասար]
# [հավասար]
# [օրենքի, հավասար]
# [խտրականության, հավասար]
# [խտրականության, հավասար]
# [խտրականության, հավասար]
# [հավասար]
# [ունեն, հավասար]
# [հավասար]
# [հավասար, պաշտպանվելու, իրավունք, ունեն, հավասար]
# [պաշտպանվելու, իրավունք, ունեն, հավասար]
# [իրավունք, ունեն, հավասար]
# [ունեն, հավասար]
# [հավասար]
# [ունեն]
# []
# [իրավունք, ունեն]
# [իրավունք, ունեն]
# [ունեն]
# [խտրականության, ունեն]
# [խտրականության, ունեն]
# [խտրականության, ունեն]
# [ունեն]
# [խախտվում, խտրականության, ունեն]
# [խախտվում, խտրականության, ունեն]
# [խտրականության, ունեն]
# [խախտվում, խտրականության, ունեն]
# [Հռչակագիրը, խախտվում, խտրականության, ունեն]
# [խախտվում, խտրականության, ունեն]
# [սադրանքի, Հռչակագիրը, խախտվում, խտրականության, ունեն]
# [ընդդեմ, խտրականության, մղող, սադրանքի, Հռչակագիրը, խախտվում, խտրականության, ունեն]
# [խտրականության, մղող, սադրանքի, Հռչակագիրը, խախտվում, խտրականության, ունեն]
# [խտրականության, մղող, սադրանքի, Հռչակագիրը, խախտվում, խտրականության, ունեն]
# [մղող, սադրանքի, Հռչակագիրը, խախտվում, խտրականության, ունեն]
# [սադրանքի, Հռչակագիրը, խախտվում, խտրականության, ունեն]
# [սադրանքի, Հռչակագիրը, խախտվում, խտրականության, ունեն]
# [Հռչակագիրը, խախտվում, խտրականության, ունեն]
# [ունեն]
# []
# [Հոդված]
# [ունի]
# [Ամեն, ունի]
# []
# [դատարանների, իրավունք, ունի]
# [դատարանների, իրավունք, ունի]
# [իրավունք, ունի]
# [դատարանների, իրավունք, ունի]
# [իրավունքների, վերականգնման, իրավունք, ունի]
# [վերականգնման, իրավունք, ունի]
# [վերականգնման, իրավունք, ունի]
# [իրավունք, ունի]
# [ունի]
# [խախտվում, ունի]
# [խախտվում, ունի]
# [ունի]
# [խախտվում, ունի]
# [սահմանված, իրավունքները, խախտվում, ունի]
# [օրենքով, սահմանված, իրավունքները, խախտվում, ունի]
# [սահմանված, իրավունքները, խախտվում, ունի]
# [իրավունքները, խախտվում, ունի]
# [իրավունքները, խախտվում, ունի]
# [իրավունքները, խախտվում, ունի]
# [խախտվում, ունի]
# [ունի]
# []
# [Հոդված]
# [կարող]
# [Ոչ, կարող]
# [կարող]
# []
# [կարող]
# [կալանքի, ենթարկվել, կարող]
# [ենթարկվել, կարող]
# [բանտարկության, կալանքի, ենթարկվել, կարող]
# [կալանքի, ենթարկվել, կարող]
# [արտաքսման, բանտարկության, կալանքի, ենթարկվել, կարող]
# [բանտարկության, կալանքի, ենթարկվել, կարող]
# [կարող]
# []
# [Հոդված]
# [համարև, ունի]
# [Ամեն, համարև, ունի]
# [իրավունքների, սահմանման, համարև, ունի]
# [սահմանման, համարև, ունի]
# [պարտականությունների, իրավունքների, սահմանման, համարև, ունի]
# [իրավունքների, սահմանման, համարև, ունի]
# [համարև, ունի]
# [ունի]
# [ցանկացած, մեղադրանքի, դեպքում, ունի]
# [իր, ցանկացած, մեղադրանքի, դեպքում, ունի]
# [մեղադրանքի, դեպքում, ունի]
# [մեղադրանքի, դեպքում, ունի]
# [դեպքում, ունի]
# [ունի]
# [հավասարության, դեպքում, ունի]
# [հավասարության, դեպքում, ունի]
# [դեպքում, ունի]
# [հավասարության, դեպքում, ունի]
# [հիման, հավասարության, դեպքում, ունի]
# [ունի]
# [ունի]
# []
# [արդարացի, ունի]
# [արդարացի, ունի]
# [գործը, արդարացի, ունի]
# [արդարացի, ունի]
# [ունի]
# [լսվի, ունի]
# [լսվի, ունի]
# [ունի]
# [դատարանի, լսվի, ունի]
# [անկող, անկախ, դատարանի, լսվի, ունի]
# [անկախ, դատարանի, լսվի, ունի]
# [դատարանի, լսվի, ունի]
# [լսվի, ունի]
# [դատարանի, լսվի, ունի]
# [ունի]
# []
# [Հոդված]
# [ունի]
# [1, ունի]
# [մեղադրվող, մարդ, ունի]
# [Հանցագործության, մեղադրվող, մարդ, ունի]
# [մարդ, ունի]
# [մարդ, ունի]
# [ունի]
# [ունի]
# []
# [համարվել, ունի]
# [ունի]
# [ապացուցված, ունի]
# [քանի, ապացուցված, ունի]
# [մեղքը, ապացուցված, ունի]
# [ապացուցված, ունի]
# [ապացուցված, ունի]
# [ունի]
# [նախատեսված, դատաքննությամբ, ապացուցված, ունի]
# [դատաքննությամբ, ապացուցված, ունի]
# [դատաքննությամբ, ապացուցված, ունի]
# [ապացուցված, ունի]
# [ապահովվեն, դատաքննությամբ, ապացուցված, ունի]
# [ժամանակ, ապահովվեն, դատաքննությամբ, ապացուցված, ունի]
# [ապահովվեն, դատաքննությամբ, ապացուցված, ունի]
# [դատաքննությամբ, ապացուցված, ունի]
# [պաշտպանության, երաշխիքները, ապահովվեն, դատաքննությամբ, ապացուցված, ունի]
# [երաշխիքները, ապահովվեն, դատաքննությամբ, ապացուցված, ունի]
# [պաշտպանության, երաշխիքները, ապահովվեն, դատաքննությամբ, ապացուցված, ունի]
# [երաշխիքները, ապահովվեն, դատաքննությամբ, ապացուցված, ունի]
# [երաշխիքները, ապահովվեն, դատաքննությամբ, ապացուցված, ունի]
# [ապահովվեն, դատաքննությամբ, ապացուցված, ունի]
# [ունի]
# [կարող]
# [2, կարող]
# [կարող]
# [Ոչ, կարող]
# [կարող]
# []
# [կարող]
# [թողման, դատապարտվել, կարող]
# [որեւիցէ, արարքի, թողման, դատապարտվել, կարող]
# [արարքի, թողման, դատապարտվել, կարող]
# [թողման, դատապարտվել, կարող]
# [բաց, արարքի, թողման, դատապարտվել, կարող]
# [արարքի, թողման, դատապարտվել, կարող]
# [դատապարտվել, կարող]
# [թողման, դատապարտվել, կարող]
# [կատարվել, թողման, դատապարտվել, կարող]
# [կատարվել, թողման, դատապարտվել, կարող]
# [թողման, դատապարտվել, կարող]
# [կատարվել, թողման, դատապարտվել, կարող]
# [ժամանակ, կատարվել, թողման, դատապարտվել, կարող]
# [կատարվել, թողման, դատապարտվել, կարող]
# [համարվել, ժամանակ, կատարվել, թողման, դատապարտվել, կարող]
# [համարվել, ժամանակ, կատարվել, թողման, դատապարտվել, կարող]
# [համարվել, ժամանակ, կատարվել, թողման, դատապարտվել, կարող]
# [օրենքով, համարվել, ժամանակ, կատարվել, թողման, դատապարտվել, կարող]
# [միջազգային, ազգային, օրենքով, համարվել, ժամանակ, կատարվել, թողման, դատապարտվել, կարող]
# [ազգային, օրենքով, համարվել, ժամանակ, կատարվել, թողման, դատապարտվել, կարող]
# [համարվել, ժամանակ, կատարվել, թողման, դատապարտվել, կարող]
# [համարվել, ժամանակ, կատարվել, թողման, դատապարտվել, կարող]
# [համարվել, ժամանակ, կատարվել, թողման, դատապարտվել, կարող]
# [ժամանակ, կատարվել, թողման, դատապարտվել, կարող]
# [կարող]
# [կարող]
# []
# [կարող]
# [պատիժ, սահմանվել, կարող]
# [ծանր, պատիժ, սահմանվել, կարող]
# [պատիժ, սահմանվել, կարող]
# [սահմանվել, կարող]
# [այն, պատիժ, սահմանվել, կարող]
# [այն, պատիժ, սահմանվել, կարող]
# [պատիժ, սահմանվել, կարող]
# [կիրառվում, այն, պատիժ, սահմանվել, կարող]
# [կիրառվում, այն, պատիժ, սահմանվել, կարող]
# [այն, պատիժ, սահմանվել, կարող]
# [կիրառվում, այն, պատիժ, սահմանվել, կարող]
# [կատարման, կիրառվում, այն, պատիժ, սահմանվել, կարող]
# [կիրառվում, այն, պատիժ, սահմանվել, կարող]
# [կատարման, կիրառվում, այն, պատիժ, սահմանվել, կարող]
# [կարող]
# []
# [Հոդված]
# [կարող]
# [Ոչ, կարող]
# [կարող]
# []
# [կարող]
# [միջամտության, կյանքի, ենթարկվել, կարող]
# [կյանքի, ենթարկվել, կարող]
# [կյանքի, ենթարկվել, կարող]
# [կյանքի, ենթարկվել, կարող]
# [ընտանեկան, անձնական, կյանքի, ենթարկվել, կարող]
# [անձնական, կյանքի, ենթարկվել, կարող]
# [ենթարկվել, կարող]
# [կյանքի, ենթարկվել, կարող]
# [ոտնձգության, կյանքի, ենթարկվել, կարող]
# [տան, կամայական, ոտնձգության, կյանքի, ենթարկվել, կարող]
# [կամայական, ոտնձգության, կյանքի, ենթարկվել, կարող]
# [թղթակցությանև, տան, կամայական, ոտնձգության, կյանքի, ենթարկվել, կարող]
# [տան, կամայական, ոտնձգության, կյանքի, ենթարկվել, կարող]
# [պատվի, տան, կամայական, ոտնձգության, կյանքի, ենթարկվել, կարող]
# [պատվի, տան, կամայական, ոտնձգության, կյանքի, ենթարկվել, կարող]
# [տան, կամայական, ոտնձգության, կյանքի, ենթարկվել, կարող]
# [համբավի, պատվի, տան, կամայական, ոտնձգության, կյանքի, ենթարկվել, կարող]
# [պատվի, տան, կամայական, ոտնձգության, կյանքի, ենթարկվել, կարող]
# [տան, կամայական, ոտնձգության, կյանքի, ենթարկվել, կարող]
# [ոտնձգության, կյանքի, ենթարկվել, կարող]
# [կյանքի, ենթարկվել, կարող]
# [կարող]
# [ունի]
# [Ամեն, ունի]
# []
# [պաշտպանվելու, իրավունք, ունի]
# [իրավունք, ունի]
# [ունի]
# [միջամտության, ունի]
# [միջամտության, ունի]
# [ունի]
# [ոտնձգության, միջամտության, ունի]
# [միջամտության, ունի]
# [ունի]
# []
# [Հոդված]
# [ունի]
# [1, ունի]
# [ունի]
# [Ամեն, ունի]
# []
# [ունի]
# [վայր, ընտրելու, ունի]
# [ընտրելու, ունի]
# [ունի]
# [իրավունք, ունի]
# [ունի]
# [պետության, սահմաններում, ունի]
# [սահմաններում, ունի]
# [ունի]
# [ունի]
# [ունի]
# [2, ունի]
# [ունի]
# [Ամեն, ունի]
# []
# [երկրից, ունի]
# [ունի]
# [այդ, երկրից, ունի]
# [երկրից, ունի]
# [այդ, երկրից, ունի]
# [երկրից, հեռանալուև, իրավունք, ունի]
# [հեռանալուև, իրավունք, ունի]
# [իրավունք, ունի]
# [երկիր, վերադառնալու, իրավունք, ունի]
# [վերադառնալու, իրավունք, ունի]
# [իրավունք, ունի]
# [ունի]
# [ունի]
# []
# [Հոդված]
# [ունի]
# [1, ունի]
# [ունի]
# [Ամեն, ունի]
# [ունի]
# []
# [երկրներում, որոնելև, ունի]
# [որոնելև, ունի]
# [որոնելև, ունի]
# [որոնելև, ունի]
# [ունի]
# [օգտվել, որոնելև, ունի]
# [որոնելև, ունի]
# [ունի]
# [կարող]
# [2, կարող]
# [իրավունքը, կարող]
# [կարող]
# [կարող]
# []
# [կարող]
# [հանցագործությունների, հարուցված, հետապնդությունների, դեպքում, գործադրվել, կարող]
# [հանցագործությունների, հարուցված, հետապնդությունների, դեպքում, գործադրվել, կարող]
# [հարուցված, հետապնդությունների, դեպքում, գործադրվել, կարող]
# [արարքների, հանցագործությունների, հարուցված, հետապնդությունների, դեպքում, գործադրվել, կարող]
# [հանցագործությունների, հարուցված, հետապնդությունների, դեպքում, գործադրվել, կարող]
# [հանցագործությունների, հարուցված, հետապնդությունների, դեպքում, գործադրվել, կարող]
# [հետապնդությունների, դեպքում, գործադրվել, կարող]
# [դեպքում, գործադրվել, կարող]
# [գործադրվել, կարող]
# [հակասում, հետապնդությունների, դեպքում, գործադրվել, կարող]
# [հակասում, հետապնդությունների, դեպքում, գործադրվել, կարող]
# [հետապնդությունների, դեպքում, գործադրվել, կարող]
# [հակասում, հետապնդությունների, դեպքում, գործադրվել, կարող]
# [ազգերի, նպատակներին, հակասում, հետապնդությունների, դեպքում, գործադրվել, կարող]
# [նպատակներին, հակասում, հետապնդությունների, դեպքում, գործադրվել, կարող]
# [հակասում, հետապնդությունների, դեպքում, գործադրվել, կարող]
# [սկզբունքներին, նպատակներին, հակասում, հետապնդությունների, դեպքում, գործադրվել, կարող]
# [նպատակներին, հակասում, հետապնդությունների, դեպքում, գործադրվել, կարող]
# [կարող]
# []
# [Հոդված]
# [ունի]
# [1, ունի]
# [ունի]
# [Ամեն, ունի]
# []
# [իրավունք, ունի]
# [ունի]
# [ունի]
# [կարող]
# [2, կարող]
# [կարող]
# [Ոչ, կարող]
# [կարող]
# []
# [զրկվել, կարող]
# [կարող]
# [քաղաքացիությունից, փոխելու, իրավունքից, զրկվել, կարող]
# [փոխելու, իրավունքից, զրկվել, կարող]
# [քաղաքացիությունը, քաղաքացիությունից, փոխելու, իրավունքից, զրկվել, կարող]
# [քաղաքացիությունից, փոխելու, իրավունքից, զրկվել, կարող]
# [իրավունքից, զրկվել, կարող]
# [զրկվել, կարող]
# [կարող]
# []
# [Հոդված]
# [տղամարդիկ]
# [1, տղամարդիկ]
# [տղամարդիկ]
# []
# [կանայք, տղամարդիկ]
# [տղամարդիկ]
# [ցեղային, տղամարդիկ]
# [ցեղային, տղամարդիկ]
# [ցեղային, տղամարդիկ]
# [տղամարդիկ]
# [սահմանափակման, ցեղային, տղամարդիկ]
# [սահմանափակման, ցեղային, տղամարդիկ]
# [կրոնական, ազգային, սահմանափակման, ցեղային, տղամարդիկ]
# [ազգային, սահմանափակման, ցեղային, տղամարդիկ]
# [ցեղային, տղամարդիկ]
# [ունեն, տղամարդիկ]
# [ունեն, տղամարդիկ]
# [տղամարդիկ]
# [ընտանիք, հիմնել, ունեն, տղամարդիկ]
# [հիմնել, ունեն, տղամարդիկ]
# [ունեն, տղամարդիկ]
# [ունեն, տղամարդիկ]
# [ունեն]
# [իրավունքներ, ունեն]
# [ունեն]
# []
# [ունեն]
# [ամուսնալուծության, ունեն]
# [ընթացքումև, ամուսնալուծության, ունեն]
# [ամուսնալուծության, ունեն]
# [ունեն]
# [ամուսնալուծության, ունեն]
# [ունեն]
# [կարող]
# [2, կարող]
# [կարող]
# []
# [կարող]
# [կարող]
# [ամուսնացող, կողմերի, համաձայնության, դեպքում, կայանալ, կարող]
# [կողմերի, համաձայնության, դեպքում, կայանալ, կարող]
# [համաձայնության, դեպքում, կայանալ, կարող]
# [համաձայնության, դեպքում, կայանալ, կարող]
# [ազատ, լիարժեք, համաձայնության, դեպքում, կայանալ, կարող]
# [լիարժեք, համաձայնության, դեպքում, կայանալ, կարող]
# [դեպքում, կայանալ, կարող]
# [կայանալ, կարող]
# [կարող]
# [ունի]
# [3, ունի]
# [ունի]
# [բջիջն, ունի]
# [բջիջն, ունի]
# [հիմնական, բնական, բջիջն, ունի]
# [բնական, բջիջն, ունի]
# [ունի]
# [պաշտպանվելու, իրավունք, ունի]
# [իրավունք, ունի]
# [ունի]
# []
# [ունի]
# [պետության, հասարակության, ունի]
# [հասարակության, ունի]
# [հասարակության, ունի]
# [ունի]
# []
# [Հոդված]
# [ունի]
# [1, ունի]
# [ունի]
# [Ամեն, ունի]
# []
# [ունենալու, իրավունք, ունի]
# [իրավունք, ունի]
# [ունի]
# [մենակ, իրավունք, ունի]
# [մենակ, իրավունք, ունի]
# [իրավունք, ունի]
# [ուրիշների, մենակ, իրավունք, ունի]
# [ուրիշների, մենակ, իրավունք, ունի]
# [այնպես, ուրիշների, մենակ, իրավունք, ունի]
# [մենակ, իրավունք, ունի]
# [ուրիշների, մենակ, իրավունք, ունի]
# [ուրիշների, մենակ, իրավունք, ունի]
# [ունի]
# [կարող]
# [2, կարող]
# [կարող]
# [Ոչ, կարող]
# [կարող]
# []
# [զրկվել, կարող]
# [կարող]
# [սեփականությունից, զրկվել, կարող]
# [զրկվել, կարող]
# [կարող]
# []
# [Հոդված]
# [ունի]
# [Յուրաքանչյուր, ունի]
# []
# [ազատության, իրավունք, ունի]
# [խղճի, մտքի, ազատության, իրավունք, ունի]
# [մտքի, ազատության, իրավունք, ունի]
# [դավանանքի, մտքի, ազատության, իրավունք, ունի]
# [մտքի, ազատության, իրավունք, ունի]
# [իրավունք, ունի]
# [ունի]
# [ներառնում, ունի]
# [իրավունքը, ներառնում, ունի]
# [ներառնում, ունի]
# [ունի]
# [ներառնում, ունի]
# [դավանանքը, փոխելու, ազատությունև, ներառնում, ունի]
# [փոխելու, ազատությունև, ներառնում, ունի]
# [համոզմունքները, դավանանքը, փոխելու, ազատությունև, ներառնում, ունի]
# [դավանանքը, փոխելու, ազատությունև, ներառնում, ունի]
# [ազատությունև, ներառնում, ունի]
# [ներառնում, ունի]
# [դավանանքին, փոխելու, ազատությունև, ներառնում, ունի]
# [փոխելու, ազատությունև, ներառնում, ունի]
# [համոզմունքներին, հետեւելու, ազատություն, ներառնում, ունի]
# [հետեւելու, ազատություն, ներառնում, ունի]
# [ազատություն, ներառնում, ունի]
# [ներառնում, ունի]
# [համատեղ, ազատություն, ներառնում, ունի]
# [համատեղ, ազատություն, ներառնում, ունի]
# [համատեղ, ազատություն, ներառնում, ունի]
# [համատեղ, ազատություն, ներառնում, ունի]
# [մենակ, համատեղ, ազատություն, ներառնում, ունի]
# [ազատություն, ներառնում, ունի]
# [հրապարակայնորեն, համատեղ, ազատություն, ներառնում, ունի]
# [համատեղ, ազատություն, ներառնում, ունի]
# [գաղտնի, համատեղ, ազատություն, ներառնում, ունի]
# [համատեղ, ազատություն, ներառնում, ունի]
# [քարոզի, համատեղ, ազատություն, ներառնում, ունի]
# [համատեղ, ազատություն, ներառնում, ունի]
# [ժամերգության, քարոզի, համատեղ, ազատություն, ներառնում, ունի]
# [քարոզի, համատեղ, ազատություն, ներառնում, ունի]
# [կրոնական, քարոզի, համատեղ, ազատություն, ներառնում, ունի]
# [քարոզի, համատեղ, ազատություն, ներառնում, ունի]
# [ծիսական, կրոնական, քարոզի, համատեղ, ազատություն, ներառնում, ունի]
# [կրոնական, քարոզի, համատեղ, ազատություն, ներառնում, ունի]
# [քարոզի, համատեղ, ազատություն, ներառնում, ունի]
# [քարոզի, համատեղ, ազատություն, ներառնում, ունի]
# [ունի]
# []
# [Հոդված]
# [ունի]
# [Ամեն, ունի]
# []
# [ունենալուև, իրավունք, ունի]
# [իրավունք, ունի]
# [իրավունք, ունի]
# [ունի]
# [ներառնում, ունի]
# [իրավունքը, ներառնում, ունի]
# [ներառնում, ունի]
# [ունի]
# [ներառնում, ունի]
# [անարգել, ներառնում, ունի]
# [ներառնում, ունի]
# [մնալուև, տեղեկություններ, անարգել, ներառնում, ունի]
# [տեղեկություններ, անարգել, ներառնում, ունի]
# [անարգել, ներառնում, ունի]
# [որոնելու, անարգել, ներառնում, ունի]
# [որոնելու, անարգել, ներառնում, ունի]
# [անարգել, ներառնում, ունի]
# [ստանալու, ազատություն, որոնելու, անարգել, ներառնում, ունի]
# [ազատություն, որոնելու, անարգել, ներառնում, ունի]
# [տարածելու, ստանալու, ազատություն, որոնելու, անարգել, ներառնում, ունի]
# [ստանալու, ազատություն, որոնելու, անարգել, ներառնում, ունի]
# [որոնելու, անարգել, ներառնում, ունի]
# [միջոցներով, ազատություն, որոնելու, անարգել, ներառնում, ունի]
# [ցանկացած, միջոցներով, ազատություն, որոնելու, անարգել, ներառնում, ունի]
# [միջոցներով, ազատություն, որոնելու, անարգել, ներառնում, ունի]
# [ազատություն, որոնելու, անարգել, ներառնում, ունի]
# [սահմաններից, միջոցներով, ազատություն, որոնելու, անարգել, ներառնում, ունի]
# [սահմաններից, միջոցներով, ազատություն, որոնելու, անարգել, ներառնում, ունի]
# [սահմաններից, միջոցներով, ազատություն, որոնելու, անարգել, ներառնում, ունի]
# [միջոցներով, ազատություն, որոնելու, անարգել, ներառնում, ունի]
# [ունի]
# []
# [Հոդված]
# [ունի]
# [1, ունի]
# [ունի]
# [Յուրաքանչյուր, ունի]
# []
# [հավաքների, իրավունք, ունի]
# [իրավունք, ունի]
# [կազմելու, հավաքների, իրավունք, ունի]
# [կազմելու, հավաքների, իրավունք, ունի]
# [հավաքների, իրավունք, ունի]
# [ունի]
# [ունի]
# [կարող]
# [2, կարող]
# [կարող]
# [Ոչ, կարող]
# [կարող]
# []
# [անդամակցվել, կարող]
# [կարող]
# [անդամակցվել, կարող]
# [անդամակցվել, կարող]
# [կարող]
# []
# [Հոդված]
# [ունի]
# [1, ունի]
# [ունի]
# [Յուրաքանչյուր, ունի]
# [ունի]
# []
# [ունի]
# [երկրի, կառավարմանը, մասնակցել, ունի]
# [կառավարմանը, մասնակցել, ունի]
# [մասնակցել, ունի]
# [ներկայացուցիչների, կառավարմանը, մասնակցել, ունի]
# [ներկայացուցիչների, կառավարմանը, մասնակցել, ունի]
# [ընտրված, ներկայացուցիչների, կառավարմանը, մասնակցել, ունի]
# [ընտրված, ներկայացուցիչների, կառավարմանը, մասնակցել, ունի]
# [ներկայացուցիչների, կառավարմանը, մասնակցել, ունի]
# [կառավարմանը, մասնակցել, ունի]
# [ներկայացուցիչների, կառավարմանը, մասնակցել, ունի]
# [ունի]
# [ունի]
# [2, ունի]
# [ունի]
# [Յուրաքանչյուր, ունի]
# [երկրում, ունի]
# [ունի]
# []
# [ծառայություն, կատարելու, իրավունք, ունի]
# [կատարելու, իրավունք, ունի]
# [իրավունք, ունի]
# [իրավունք, ունի]
# [ունի]
# [ունի]
# [լինի]
# [3, լինի]
# [կամքը, լինի]
# [լինի]
# [լինի]
# [լինի]
# []
# [իրավազորության, հիմքը, լինի]
# [հիմքը, լինի]
# [լինի]
# [լինեն, լինի]
# [կամքի, արտահայտությունը, լինեն, լինի]
# [արտահայտությունը, լինեն, լինի]
# [լինեն, լինի]
# [լինեն, լինի]
# [լինեն, լինի]
# [լինի]
# [ընտրությունները, լինեն, լինի]
# [անեղծ, պարբերական, ընտրությունները, լինեն, լինի]
# [պարբերական, ընտրությունները, լինեն, լինի]
# [լինեն, լինի]
# [իրագործվեն, ընտրությունները, լինեն, լինի]
# [իրագործվեն, ընտրությունները, լինեն, լինի]
# [իրագործվեն, ընտրությունները, լինեն, լինի]
# [իրագործվեն, ընտրությունները, լինեն, լինի]
# [ընտրությունները, լինեն, լինի]
# [իրավունքի, իրագործվեն, ընտրությունները, լինեն, լինի]
# [հավասար, համընդհանուր, իրավունքի, իրագործվեն, ընտրությունները, լինեն, լինի]
# [համընդհանուր, իրավունքի, իրագործվեն, ընտրությունները, լինեն, լինի]
# [իրավունքի, իրագործվեն, ընտրությունները, լինեն, լինի]
# [իրագործվեն, ընտրությունները, լինեն, լինի]
# [իրավունքի, իրագործվեն, ընտրությունները, լինեն, լինի]
# [հիման, իրավունքի, իրագործվեն, ընտրությունները, լինեն, լինի]
# [քվեարկության, իրավունքի, իրագործվեն, ընտրությունները, լինեն, լինի]
# [քվեարկության, իրավունքի, իրագործվեն, ընտրությունները, լինեն, լինի]
# [իրավունքի, իրագործվեն, ընտրությունները, լինեն, լինի]
# [ընթացակարգերի, քվեարկության, իրավունքի, իրագործվեն, ընտրությունները, լինեն, լինի]
# [ազատ, ընթացակարգերի, քվեարկության, իրավունքի, իրագործվեն, ընտրությունները, լինեն, լինի]
# [ընթացակարգերի, քվեարկության, իրավունքի, իրագործվեն, ընտրությունները, լինեն, լինի]
# [ընթացակարգերի, քվեարկության, իրավունքի, իրագործվեն, ընտրությունները, լինեն, լինի]
# [քվեարկության, իրավունքի, իրագործվեն, ընտրությունները, լինեն, լինի]
# [իրավունքի, իրագործվեն, ընտրությունները, լինեն, լինի]
# [լինի]
# []
# [Հոդված]
# [ունի]
# [Յուրաքանչյուր, ունի]
# [անդամ, ունի]
# [անդամ, ունի]
# [անդամ, ունի]
# [ունի]
# [ունի]
# [ապահովության, իրավունք, ունի]
# [իրավունք, ունի]
# [ունի]
# []
# [օգտվում, ունի]
# [ունի]
# [օգտվում, ունի]
# [արժանապատվությանև, անձի, զարգացման, ունի]
# [անձի, զարգացման, ունի]
# [անձի, զարգացման, ունի]
# [զարգացման, ունի]
# [զարգացման, ունի]
# [ունի]
# [զարգացման, ունի]
# [իրավունքներից, ջանքերի, զարգացման, ունի]
# [իրավունքներից, ջանքերի, զարգացման, ունի]
# [սոցիալական, տնտեսական, իրավունքներից, ջանքերի, զարգացման, ունի]
# [տնտեսական, իրավունքներից, ջանքերի, զարգացման, ունի]
# [մշակութային, տնտեսական, իրավունքներից, ջանքերի, զարգացման, ունի]
# [տնտեսական, իրավունքներից, ջանքերի, զարգացման, ունի]
# [ջանքերի, զարգացման, ունի]
# [ջանքերի, զարգացման, ունի]
# [զարգացման, ունի]
# [համագործակցության, ջանքերի, զարգացման, ունի]
# [համագործակցության, ջանքերի, զարգացման, ունի]
# [ջանքերի, զարգացման, ունի]
# [ջանքերի, զարգացման, ունի]
# [կառուցվածքին, ջանքերի, զարգացման, ունի]
# [պետության, կառուցվածքին, ջանքերի, զարգացման, ունի]
# [կառուցվածքին, ջանքերի, զարգացման, ունի]
# [ջանքերի, զարգացման, ունի]
# [ռեսուրսներին, կառուցվածքին, ջանքերի, զարգացման, ունի]
# [կառուցվածքին, ջանքերի, զարգացման, ունի]
# [կառուցվածքին, ջանքերի, զարգացման, ունի]
# [ունի]
# []
# [Հոդված]
# [ունի]
# [1, ունի]
# [ունի]
# [Յուրաքանչյուր, ունի]
# []
# [ունի]
# [ընտրության, աշխատանքի, ունի]
# [ընտրության, աշխատանքի, ունի]
# [ընտրության, աշխատանքի, ունի]
# [աշխատանքի, ունի]
# [արդարացի, աշխատանքի, ունի]
# [աշխատանքի, ունի]
# [նպաստավոր, արդարացի, աշխատանքի, ունի]
# [արդարացի, աշխատանքի, ունի]
# [պայմաններիև, պաշտպանվելու, վունք, ունի]
# [պաշտպանվելու, վունք, ունի]
# [պաշտպանվելու, վունք, ունի]
# [վունք, ունի]
# [վունք, ունի]
# [ունի]
# [ունի]
# [ունի]
# [2, ունի]
# [ունի]
# [Յուրաքանչյուր, ունի]
# [խտրականության, ունի]
# [խտրականության, ունի]
# [խտրականության, ունի]
# [ունի]
# [ունի]
# []
# [աշխատանքի, վարձատրության, իրավունք, ունի]
# [վարձատրության, իրավունք, ունի]
# [աշխատանքի, վարձատրության, իրավունք, ունի]
# [վարձատրության, իրավունք, ունի]
# [իրավունք, ունի]
# [ունի]
# [ունի]
# [ունի]
# [3, ունի]
# [ունի]
# [Յուրաքանչյուր, ունի]
# []
# [իրավունք, ունի]
# [համապատասխան, արդարացի, իրավունք, ունի]
# [արդարացի, իրավունք, ունի]
# [իրավունք, ունի]
# [ունի]
# [ապահովվի, իրավունք, ունի]
# [ապահովվի, իրավունք, ունի]
# [իրավունք, ունի]
# [արժանապատվությանը, վայել, գոյությունը, ապահովվի, իրավունք, ունի]
# [վայել, գոյությունը, ապահովվի, իրավունք, ունի]
# [գոյությունը, ապահովվի, իրավունք, ունի]
# [գոյությունը, ապահովվի, իրավունք, ունի]
# [ընտանիքը, իր, գոյությունը, ապահովվի, իրավունք, ունի]
# [ընտանիքը, իր, գոյությունը, ապահովվի, իրավունք, ունի]
# [իր, գոյությունը, ապահովվի, իրավունք, ունի]
# [ապահովվի, իրավունք, ունի]
# [լրացվի, ունի]
# [լրացվի, ունի]
# [դեպքում, լրացվի, ունի]
# [լրացվի, ունի]
# [ունի]
# [ապավության, միջոցներով, լրացվի, ունի]
# [միջոցներով, լրացվի, ունի]
# [միջոցներով, լրացվի, ունի]
# [լրացվի, ունի]
# [ունի]
# [ունի]
# [4, ունի]
# [ունի]
# [Յուրաքանչյուր, ունի]
# []
# [շահերը, պաշտպանելու, ստեղծելուև, ունի]
# [պաշտպանելու, ստեղծելուև, ունի]
# [ստեղծելուև, ունի]
# [պաշտպանելու, ստեղծելուև, ունի]
# [միություններ, ստեղծելուև, ունի]
# [ստեղծելուև, ունի]
# [ունի]
# [իրավունք, ստեղծելուև, ունի]
# [իրավունք, ստեղծելուև, ունի]
# [ստեղծելուև, ունի]
# [ունի]
# []
# [Հոդված]
# [ունի]
# [Յուրաքանչյուր, ունի]
# []
# [ունի]
# [ժամանցի, հանգստի, ունի]
# [հանգստի, ունի]
# [այդ, հանգստի, ունի]
# [հանգստի, ունի]
# [այդ, հանգստի, ունի]
# [իրավունք, ունի]
# [ժամերի, սահմանափակմանև, արձակուրդների, իրավունք, ունի]
# [սահմանափակմանև, արձակուրդների, իրավունք, ունի]
# [սահմանափակմանև, արձակուրդների, իրավունք, ունի]
# [արձակուրդների, իրավունք, ունի]
# [արձակուրդների, իրավունք, ունի]
# [արձակուրդների, իրավունք, ունի]
# [իրավունք, ունի]
# [ունի]
# [ունի]
# []
# [Հոդված]
# [ունի]
# [1, ունի]
# [ունի]
# [Յուրաքանչյուր, ունի]
# []
# [իրավունք, ունի]
# [ունի]
# [ապահովի, իրավունք, ունի]
# [ապահովի, իրավունք, ունի]
# [ապահովի, իրավունք, ունի]
# [ընտանիքի, ապահովի, իրավունք, ունի]
# [ապահովի, իրավունք, ունի]
# [ընտանիքի, ապահովի, իրավունք, ունի]
# [իրավունք, ունի]
# [ապահովի, իրավունք, ունի]
# [բարեկեցություն, առողջություն, ապահովի, իրավունք, ունի]
# [առողջություն, ապահովի, իրավունք, ունի]
# [այդ, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [այդ, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [առողջություն, ապահովի, իրավունք, ունի]
# [հագուստ, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [բնակարան, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [սպասարկում, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [սպասարկում, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [ծառայություններև, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [ծառայություններև, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [ծառայություններև, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [իրավունք, գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [հիվանդության, գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [հաշմանդամության, հիվանդության, գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [հիվանդության, գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [այրիության, հիվանդության, գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [հիվանդության, գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [դեպքերում, գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [դեպքերում, գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [դեպքերում, գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [պայմանավորված, դեպքերում, գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [պայմանավորված, դեպքերում, գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [միջոցների, ձեռքբերումը, պայմանավորված, դեպքերում, գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [ձեռքբերումը, պայմանավորված, դեպքերում, գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [պայմանավորված, դեպքերում, գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [պայմանավորված, դեպքերում, գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [դեպքերում, գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [կախված, հանգամանքներով, պայմանավորված, դեպքերում, գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [հանգամանքներով, պայմանավորված, դեպքերում, գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [պայմանավորված, դեպքերում, գործազրկության, սնունդ, առողջություն, ապահովի, իրավունք, ունի]
# [ունի]
# [ունեն]
# [2, ունեն]
# [ունեն]
# [մանուկներն, Մայրերն, ունեն]
# [Մայրերն, ունեն]
# []
# [հոգածության, ունեն]
# [ունեն]
# [իրավունք, հոգածության, ունեն]
# [իրավունք, հոգածության, ունեն]
# [հոգածության, ունեն]
# [ունեն]
# [երեխաները, օգտվում]
# [օգտվում]
# [ամուսնությունից, օգտվում]
# [ամուսնությունից, օգտվում]
# [օգտվում]
# [կապերից, ամուսնությունից, օգտվում]
# [կապերից, ամուսնությունից, օգտվում]
# [ամուսնությունից, օգտվում]
# [օգտվում]
# []
# [օգտվում]
# [պաշտպանությունից, օգտվում]
# [պաշտպանությունից, օգտվում]
# [օգտվում]
# [օգտվում]
# []
# [Հոդված]
# [ունի]
# [1, ունի]
# [ունի]
# [Յուրաքանչյուր, ունի]
# []
# [իրավունք, ունի]
# [ունի]
# [ունի]
# [լինի]
# [տարրական, փուլերում, լինի]
# [տարրական, փուլերում, լինի]
# [փուլերում, լինի]
# [հանրակրթական, տարրական, փուլերում, լինի]
# [տարրական, փուլերում, լինի]
# [լինի]
# [լինի]
# [լինի]
# [լինի]
# []
# [լինի]
# [լինի]
# [կրթությունը, լինի]
# [լինի]
# [լինի]
# [լինի]
# []
# [լինի]
# [լինի]
# [կրթությունը, լինելու]
# [մասնագիտական, Տեխնիկական, կրթությունը, լինելու]
# [Տեխնիկական, կրթությունը, լինելու]
# [լինելու]
# []
# [լինելու]
# [մատչելի, լինելու]
# [ընդհանուրի, մատչելի, լինելու]
# [լինելու]
# [հիմնված, լինելու]
# [հիմնված, լինելու]
# [կրթությունը, հիմնված, լինելու]
# [հիմնված, լինելու]
# [մատչելի, կրթությունը, հիմնված, լինելու]
# [մատչելի, կրթությունը, հիմնված, լինելու]
# [բոլորի, մատչելի, կրթությունը, հիմնված, լինելու]
# [մատչելի, կրթությունը, հիմնված, լինելու]
# [կրթությունը, հիմնված, լինելու]
# [հիմնված, լինելու]
# [լինելու]
# [հիմնված, լինելու]
# [ընդունակությունների, հիմնված, լինելու]
# [լինելու]
# [նպատակաուղղված]
# [2, նպատակաուղղված]
# [նպատակաուղղված]
# [նպատակաուղղված]
# [նպատակաուղղված]
# []
# [նպատակաուղղված]
# [զարգացմանը, նպատակաուղղված]
# [զարգացմանը, նպատակաուղղված]
# [նպատակաուղղված]
# [իրավունքների, զարգացմանը, նպատակաուղղված]
# [իրավունքների, զարգացմանը, նպատակաուղղված]
# [զարգացմանը, նպատակաուղղված]
# [ազատությունների, հարգանքի, ամրապնդմանը, զարգացմանը, նպատակաուղղված]
# [ազատությունների, հարգանքի, ամրապնդմանը, զարգացմանը, նպատակաուղղված]
# [հարգանքի, ամրապնդմանը, զարգացմանը, նպատակաուղղված]
# [ազատությունների, հարգանքի, ամրապնդմանը, զարգացմանը, նպատակաուղղված]
# [ամրապնդմանը, զարգացմանը, նպատակաուղղված]
# [զարգացմանը, նպատակաուղղված]
# [նպատակաուղղված]
# [նպաստի]
# [նպաստի]
# [նպաստի]
# []
# [ազգերի, փոխ, ըմբռնմանը, նպաստի]
# [փոխ, ըմբռնմանը, նպաստի]
# [ցեղային, ազգերի, փոխ, ըմբռնմանը, նպաստի]
# [ազգերի, փոխ, ըմբռնմանը, նպաստի]
# [խմբերի, ազգերի, փոխ, ըմբռնմանը, նպաստի]
# [խմբերի, ազգերի, փոխ, ըմբռնմանը, նպաստի]
# [ազգերի, փոխ, ըմբռնմանը, նպաստի]
# [ազգերի, փոխ, ըմբռնմանը, նպաստի]
# [ըմբռնմանը, նպաստի]
# [նպաստի]
# [հանդուրժող, ականությանն, ըմբռնմանը, նպաստի]
# [ականությանն, ըմբռնմանը, նպաստի]
# [ըմբռնմանը, նպաստի]
# [բարեկամությանըև, ականությանն, ըմբռնմանը, նպաստի]
# [ականությանն, ըմբռնմանը, նպաստի]
# [ավելի, Միավորված, ազգերի, գործունեությանը, ըմբռնմանը, նպաստի]
# [Միավորված, ազգերի, գործունեությանը, ըմբռնմանը, նպաստի]
# [Միավորված, ազգերի, գործունեությանը, ըմբռնմանը, նպաստի]
# [ազգերի, գործունեությանը, ըմբռնմանը, նպաստի]
# [գործունեությանը, ըմբռնմանը, նպաստի]
# [գործունեությանը, ըմբռնմանը, նպաստի]
# [ըմբռնմանը, նպաստի]
# [նպաստի]
# [ունեն]
# [3, ունեն]
# [ունեն]
# []
# [երեխաներին, տրվող, կրթության, տեսակի, ընտրության, իրավունք, ունեն]
# [տրվող, կրթության, տեսակի, ընտրության, իրավունք, ունեն]
# [կրթության, տեսակի, ընտրության, իրավունք, ունեն]
# [տեսակի, ընտրության, իրավունք, ունեն]
# [ընտրության, իրավունք, ունեն]
# [իրավունք, ունեն]
# [իրավունք, ունեն]
# [ունեն]
# [ունեն]
# []
# [Հոդված]
# [ունի]
# [1, ունի]
# [ունի]
# [Յուրաքանչյուր, ունի]
# []
# [համայնքի, կյանքին, մասնակցելու, ունի]
# [կյանքին, մասնակցելու, ունի]
# [կյանքին, մասնակցելու, ունի]
# [մասնակցելու, ունի]
# [մասնակցելու, ունի]
# [ունի]
# [դրվատելու, մասնակցելու, ունի]
# [դրվատելու, մասնակցելու, ունի]
# [մասնակցելու, ունի]
# [մասնակցելուև, մասնակցելու, ունի]
# [առաջընթացին, մասնակցելուև, մասնակցելու, ունի]
# [մասնակցելուև, մասնակցելու, ունի]
# [մասնակցելու, ունի]
# [բարիքներից, օգտվելու, իրավունք, ունի]
# [օգտվելու, իրավունք, ունի]
# [իրավունք, ունի]
# [ունի]
# [ունի]
# [ունի]
# [2, ունի]
# [ունի]
# [Յուրաքանչյուր, ունի]
# [իրավունք, ունի]
# [ունի]
# []
# [շահերի, ունի]
# [շահերի, ունի]
# [նյութական, բարոյական, շահերի, ունի]
# [բարոյական, շահերի, ունի]
# [ունի]
# [շահերի, ունի]
# [արդյունք, շահերի, ունի]
# [արդյունք, շահերի, ունի]
# [շահերի, ունի]
# [արդյունք, շահերի, ունի]
# [հեղինակած, աշխատանքի, արդյունք, շահերի, ունի]
# [իր, հեղինակած, աշխատանքի, արդյունք, շահերի, ունի]
# [աշխատանքի, արդյունք, շահերի, ունի]
# [աշխատանքի, արդյունք, շահերի, ունի]
# [գրական, գիտական, աշխատանքի, արդյունք, շահերի, ունի]
# [գիտական, աշխատանքի, արդյունք, շահերի, ունի]
# [գեղարվեստական, գիտական, աշխատանքի, արդյունք, շահերի, ունի]
# [գիտական, աշխատանքի, արդյունք, շահերի, ունի]
# [աշխատանքի, արդյունք, շահերի, ունի]
# [արդյունք, շահերի, ունի]
# [ունի]
# []
# [Հոդված]
# [ունի]
# [Յուրաքանչյուր, ունի]
# []
# [կարգուկանոնի, իրավունք, ունի]
# [միջազգային, սոցիալական, կարգուկանոնի, իրավունք, ունի]
# [սոցիալական, կարգուկանոնի, իրավունք, ունի]
# [իրավունք, ունի]
# [ունի]
# [իրագործելի, իրավունք, ունի]
# [դեպքում, իրագործելի, իրավունք, ունի]
# [իրագործելի, իրավունք, ունի]
# [իրագործելի, իրավունք, ունի]
# [իրավունք, ունի]
# [իրագործելի, իրավունք, ունի]
# [Հռչակագրում, շարադրված, իրավունքներն, իրագործելի, իրավունք, ունի]
# [շարադրված, իրավունքներն, իրագործելի, իրավունք, ունի]
# [իրավունքներն, իրագործելի, իրավունք, ունի]
# [իրագործելի, իրավունք, ունի]
# [ազատությունները, իրավունքներն, իրագործելի, իրավունք, ունի]
# [իրավունքներն, իրագործելի, իրավունք, ունի]
# [ունի]
# []
# [Հոդված]
# [ունի]
# [1, ունի]
# [ունի]
# [Յուրաքանչյուր, ունի]
# [ունի]
# []
# [ունի]
# [համայնքի, ունի]
# [հնարավոր, ունի]
# [հնարավոր, ունի]
# [հնարավոր, ունի]
# [ունի]
# [հնարավոր, ունի]
# [անձի, զարգացումը, հնարավոր, ունի]
# [զարգացումը, հնարավոր, ունի]
# [զարգացումը, հնարավոր, ունի]
# [լիարժեք, ազատ, զարգացումը, հնարավոր, ունի]
# [ազատ, զարգացումը, հնարավոր, ունի]
# [հնարավոր, ունի]
# [ունի]
# [իրականացնելիս]
# [2, իրականացնելիս]
# [իրավունքներն, իրականացնելիս]
# [իրականացնելիս]
# [ազատություններն, իրավունքներն, իրականացնելիս]
# [իրավունքներն, իրականացնելիս]
# []
# [լինի, իրականացնելիս]
# [լինի, իրականացնելիս]
# [յուրաքանչուր, լինի, իրականացնելիս]
# [լինի, իրականացնելիս]
# [լինի, իրականացնելիս]
# [լինի, իրականացնելիս]
# [իրականացնելիս]
# [սահմանափակումների, լինի, իրականացնելիս]
# [սահմանափակումների, լինի, իրականացնելիս]
# [լինի, իրականացնելիս]
# [սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [սահմանափակումների, լինի, իրականացնելիս]
# [սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [իրավունքների, ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [ազատությունների, իրավունքների, ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [իրավունքների, ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [իրավունքների, ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [ապահովելուև, ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [ապահովելուև, ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [կարգուկանոնի, պահանջները, բավարարելու, ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [կարգուկանոնի, պահանջները, բավարարելու, ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [պահանջները, բավարարելու, ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [բարեկեցության, կարգուկանոնի, պահանջները, բավարարելու, ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [բարեկեցության, կարգուկանոնի, պահանջները, բավարարելու, ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [կարգուկանոնի, պահանջները, բավարարելու, ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [պահանջները, բավարարելու, ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [բավարարելու, ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [հասարակարգում, բավարարելու, ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [բավարարելու, ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [բարոյականության, ճանաչում, սահմանված, սահմանափակումների, լինի, իրականացնելիս]
# [իրականացնելիս]
# [չպետք]
# [3, չպետք]
# [իրավունքների, իրականացումը, դեպքում, չպետք]
# [իրականացումը, դեպքում, չպետք]
# [ազատությունների, իրավունքների, իրականացումը, դեպքում, չպետք]
# [իրավունքների, իրականացումը, դեպքում, չպետք]
# [դեպքում, չպետք]
# [դեպքում, չպետք]
# [ոչ, դեպքում, չպետք]
# [չպետք]
# []
# [չպետք]
# [ազգերի, նպատակներին, չպետք]
# [ազգերի, նպատակներին, չպետք]
# [նպատակներին, չպետք]
# [չպետք]
# [սկզբունքներին, նպատակներին, չպետք]
# [նպատակներին, չպետք]
# [չպետք]
# []
# [Հոդված]
# [Հռչակագրում, կարող]
# [կարող]
# [բան, կարող]
# [ոչ, բան, կարող]
# [կարող]
# [կարող]
# []
# [կարող]
# [իրավունքի, տրամադրում, կարող]
# [տրամադրում, կարող]
# [տրամադրում, կարող]
# [կարող]
# [տրամադրում, կարող]
# [տրամադրում, կարող]
# [խմբի, պետության, տրամադրում, կարող]
# [խմբի, պետության, տրամադրում, կարող]
# [պետության, տրամադրում, կարող]
# [անձանց, զբաղվելու, որեւէ, գործունեությամբ, տրամադրում, կարող]
# [անձանց, զբաղվելու, որեւէ, գործունեությամբ, տրամադրում, կարող]
# [զբաղվելու, որեւէ, գործունեությամբ, տրամադրում, կարող]
# [որեւէ, գործունեությամբ, տրամադրում, կարող]
# [որեւէ, գործունեությամբ, տրամադրում, կարող]
# [գործունեությամբ, տրամադրում, կարող]
# [տրամադրում, կարող]
# [արարքով, գործունեությամբ, տրամադրում, կարող]
# [գործունեությամբ, տրամադրում, կարող]
# [ուղղված, որեւէ, գործունեությամբ, տրամադրում, կարող]
# [ուղղված, որեւէ, գործունեությամբ, տրամադրում, կարող]
# [որեւէ, գործունեությամբ, տրամադրում, կարող]
# [ուղղված, որեւէ, գործունեությամբ, տրամադրում, կարող]
# [շարադրված, ազատությունների, ոչնչացմանը, ուղղված, որեւէ, գործունեությամբ, տրամադրում, կարող]
# [ազատությունների, ոչնչացմանը, ուղղված, որեւէ, գործունեությամբ, տրամադրում, կարող]
# [ոչնչացմանը, ուղղված, որեւէ, գործունեությամբ, տրամադրում, կարող]
# [իրավունքների, ազատությունների, ոչնչացմանը, ուղղված, որեւէ, գործունեությամբ, տրամադրում, կարող]
# [ազատությունների, ոչնչացմանը, ուղղված, որեւէ, գործունեությամբ, տրամադրում, կարող]
# [ուղղված, որեւէ, գործունեությամբ, տրամադրում, կարող]
# [կարող]
